# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image
from keras.preprocessing import image
from keras.applications import imagenet_utils
import time
from tqdm import tqdm_notebook
import glob
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-534f5bff08d2> in <module>
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 from IPython.display import Image
#       4 from keras.preprocessing import image
#       5 from keras.applications import imagenet_utils
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
plt.imshow(plt.imread('sample/0.png'))

# %%
Image(filename='sample/0.png')

# %%
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet_v2.preprocess_input(img_array_expanded_dims)

# %%
model = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
inputIm = np.array([f for f in glob.glob("sample/*.png")])
results = []
inferenceTime = []
for index, img in enumerate(inputIm):
    preprocessed_image = prepare_image(img)
    t0 = time.perf_counter()
    predictions = model.predict(preprocessed_image)
    t1 = time.perf_counter()
    inferenceTime.append(t1-t0)
    top1 = imagenet_utils.decode_predictions(predictions, top=1)[0][0][1:]
    results.append(top1)
    if top1[0] != 'warplane':
        plt.figure()
        plt.imshow(plt.imread('sample/'+str(index)+'.png'))
        plt.title("{} was misclassified for a {}".format(index, top1[0]))

# %%
results
# Out:
# [('warplane', 0.92736006)]

# %%
plt.figure()
plt.plot(inferenceTime)
plt.title("Inference time\nAverage = {:.3f} s, std dev = {:.3f} s".format(np.mean(inferenceTime), np.std(inferenceTime)))
plt.xlabel("Image number [-]")
plt.ylabel("Inference time [s]")
# Out:
# Text(0, 0.5, 'Inference time [s]')

# %%
results
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
max(score)
# Out:
# 0.9357627

# %%
# Random prediction
preprocessed_image = prepare_image(inputIm[np.random.randint(len(inputIm))])
predictions = model.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions, top=1)
print(results)
# Out:
# [[('n04552348', 'warplane', 0.91671544)]]
