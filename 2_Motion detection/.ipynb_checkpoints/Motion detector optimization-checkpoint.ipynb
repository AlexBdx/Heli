# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
# Import the log file
df = pd.read_csv("190622_201853_extrapolatedBB.csv")
# LabelEncoder for the diffMethod
#enc = LabelEncoder()
#enc.fit(df["diffMethod"])
#df["diffMethod"] = enc.transform(df["diffMethod"])
# Add the f1_score
df["f1_score"] = 1/(1/df["percentHeliTotalFiltered"]+1/df["percentFrameWithHeli"])

# Display
df.tail()
# Out:
#     gaussWindow  mgp  minArea  residualConnections  winSize  maxLevel  \
# 85           11  125        1                    5        3         7
# 86           11  125        1                    5        3         7
# 87           11  125        1                    5        3         7
# 88           11  125        1                    5        3         7
# 89           11  125        1                    5        3         7
#
#     threshold  diffMethod     realFps  avNbBoxes  avNbFilteredBoxes  \
# 85         15           0  168.642093   1.890756           1.808123
# 86         20           0  175.002489   1.795518           1.711485
# 87         25           0  169.549599   1.690476           1.630252
# 88         30           0  175.592282   1.767507           1.731092
# 89         35           0  177.266759   1.959384           1.920168
#
#     avNbHeliBox  percentHeliTotalFiltered  percentFrameWithHeli  f1_score
# 85     0.719888                  0.398141              0.714882  0.255721
# 86     0.746499                  0.436170              0.741307  0.274601
# 87     0.711485                  0.436426              0.706537  0.269782
# 88     0.649860                  0.375405              0.645341  0.237340
# 89     0.551821                  0.287381              0.547983  0.188517

# %%
nSim = len(df)-5 # Show where the last 10 values have been found
plt.figure(figsize=(25, 15))
plt.scatter(df["percentHeliTotalFiltered"][:nSim], df["percentFrameWithHeli"][:nSim], c='blue')
plt.scatter(df["percentHeliTotalFiltered"][nSim:], df["percentFrameWithHeli"][nSim:], c='red')
plt.title("Precision/Recall curve")
plt.xlabel("Precision")
plt.ylabel("Recall")
plt.axis([0, 1, 0, 1])
# Out:
# [0, 1, 0, 1]

# %%
def plotParam(param, paramRange):
    plt.figure(figsize=(25, 15))
    cmap = matplotlib.cm.get_cmap("jet")
    for index, value in enumerate(paramRange):
        #plt.figure(figsize=(25, 15))
        indexes = (df[param] == value)
        prec = df["percentHeliTotalFiltered"][indexes]
        recall = df["percentFrameWithHeli"][indexes]
        #print(min(paramRange), max(paramRange))
        if len(paramRange)>0:
            cmapValue = index/(len(paramRange)-1)
        else:
            cmapValue=0
        print(cmapValue)
        plt.scatter(prec, recall, c=cmap(cmapValue))
        xcText, ycText = np.mean(prec), np.mean(recall)
        plt.text(xcText, ycText, str(value), color=cmap(cmapValue), fontdict={"weight": "bold", "size": 30})
        plt.title(param+" impact", fontdict={"weight": "bold", "size": 30})
        plt.xlabel("Precision", fontdict={"weight": "bold", "size": 20})
        plt.ylabel("Recall", fontdict={"weight": "bold", "size": 20})
        plt.axis([0, 1, 0, 1])

# %% [markdown]
# param = ["residualConnections"]
# paramRange = [range(1, 11)]
# for i in range(len(param)):
#     plotParam(param[i], paramRange[i])

# %%
param = ["gaussWindow", "mgp", "minArea", "residualConnections", "winSize", "maxLevel", "threshold", "diffMethod"]
paramRange = [range(11, 12, 2), range(125, 126, 25), range(1, 2), range(3, 6), range(3, 4, 2), range(7, 8, 3), range(15,36,5), range(0, 1, 1)]
for i in range(len(param)):
    plotParam(param[i], paramRange[i])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 0.0
# 0.0
# 0.0
# 0.0
# 0.3333333333333333
# 0.6666666666666666
# 0.0
# 0.0
# 0.0
# 0.2
# 0.4
# 0.6
# 0.8
# 0.0

# %%
# Max f1_score
df[df["f1_score"] == max(df["f1_score"])]
# Out:
#     gaussWindow  mgp  minArea  residualConnections  winSize  maxLevel  \
# 27            3  125        1                    5        3         7
#
#     threshold  diffMethod     realFps  avNbBoxes  avNbFilteredBoxes  \
# 27         25           0  336.928013   2.137255           2.044818
#
#     avNbHeliBox  percentHeliTotalFiltered  percentFrameWithHeli  f1_score
# 27      0.85014                  0.415753              0.844228  0.278568

# %%
# Max precision
df[df["percentHeliTotalFiltered"] == max(df["percentHeliTotalFiltered"])]
# Out:
#     gaussWindow  mgp  minArea  residualConnections  winSize  maxLevel  \
# 87           11  125        1                    5        3         7
#
#     threshold  diffMethod     realFps  avNbBoxes  avNbFilteredBoxes  \
# 87         25           0  169.549599   1.690476           1.630252
#
#     avNbHeliBox  percentHeliTotalFiltered  percentFrameWithHeli  f1_score
# 87     0.711485                  0.436426              0.706537  0.269782

# %%
# Max recall
df[df["percentFrameWithHeli"] == max(df["percentFrameWithHeli"])]
# Out:
#     gaussWindow  mgp  minArea  residualConnections  winSize  maxLevel  \
# 11            1  125        1                    5        3         7
#
#     threshold  diffMethod     realFps  avNbBoxes  avNbFilteredBoxes  \
# 11         20           0  345.524402  34.092437          32.739496
#
#     avNbHeliBox  percentHeliTotalFiltered  percentFrameWithHeli  f1_score
# 11     0.890756                  0.027207              0.884562  0.026396

# %%
plt.figure()
plt.plot(sorted(df["f1_score"]))
plt.title("f1_score - current max")
plt.xlabel("Simulation [-]")
plt.ylabel("F1 - score")
# Out:
# Text(0, 0.5, 'F1 - score')
